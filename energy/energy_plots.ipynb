# %% [markdown]
# # Plotting Concrete Data

# %%
from pandas import read_excel

# %%
df = read_excel("./ENB2012_data.xlsx",sheet_name="Sheet1",header=0,nrows=769,dtype=float)
df
# Out:
#      Relative Compactness  Surface Area  Wall Area  Wall Area.1
# 0                    0.98         514.5      294.0       110.25  \
# 1                    0.98         514.5      294.0       110.25
# 2                    0.98         514.5      294.0       110.25
# 3                    0.98         514.5      294.0       110.25
# 4                    0.90         563.5      318.5       122.50
# ..                    ...           ...        ...          ...
# 763                  0.64         784.0      343.0       220.50
# 764                  0.62         808.5      367.5       220.50
# 765                  0.62         808.5      367.5       220.50
# 766                  0.62         808.5      367.5       220.50
# 767                  0.62         808.5      367.5       220.50
#
#      Overall Height  Orientation  Glazing Area  Glazing Area Distribution
# 0               7.0          2.0           0.0                        0.0  \
# 1               7.0          3.0           0.0                        0.0
# 2               7.0          4.0           0.0                        0.0
# 3               7.0          5.0           0.0                        0.0
# 4               7.0          2.0           0.0                        0.0
# ..              ...          ...           ...                        ...
# 763             3.5          5.0           0.4                        5.0
# 764             3.5          2.0           0.4                        5.0
# 765             3.5          3.0           0.4                        5.0
# 766             3.5          4.0           0.4                        5.0
# 767             3.5          5.0           0.4                        5.0
#
#      Heating Load
# 0           15.55
# 1           15.55
# 2           15.55
# 3           15.55
# 4           20.84
# ..            ...
# 763         17.88
# 764         16.54
# 765         16.44
# 766         16.48
# 767         16.64
#
# [768 rows x 9 columns]

# %%
df.loc[:, df.columns != 'Concrete compressive strength(MPa, megapascals) '].plot(
    kind="box",
    title="Box plots of each component and resulting concrete compressive strength",
    figsize=(20, 8),
)
# Out:
# <Axes: title={'center': 'Box plots of each component and resulting concrete compressive strength'}>
