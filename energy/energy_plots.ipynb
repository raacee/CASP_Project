# %% [markdown]
# # Plotting Concrete Data

# %%
from pandas import read_excel

# %%
df = read_excel("./ENB2012_data.xlsx",sheet_name="Sheet1",header=0,nrows=769,dtype=float)
df
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height
# 0                    0.98         514.5      294.0     110.25             7.0  \
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load
# 0            2.0           0.0                        0.0         15.55
# 1            3.0           0.0                        0.0         15.55
# 2            4.0           0.0                        0.0         15.55
# 3            5.0           0.0                        0.0         15.55
# 4            2.0           0.0                        0.0         20.84
# ..           ...           ...                        ...           ...
# 763          5.0           0.4                        5.0         17.88
# 764          2.0           0.4                        5.0         16.54
# 765          3.0           0.4                        5.0         16.44
# 766          4.0           0.4                        5.0         16.48
# 767          5.0           0.4                        5.0         16.64
#
# [768 rows x 9 columns]

# %%
df.loc[:, df.columns != 'Concrete compressive strength(MPa, megapascals) '].plot(
    kind="box",
    title="Box plots of each component and resulting concrete compressive strength",
    figsize=(20, 8),
    subplots=True
)
# Out:
# Relative Compactness            Axes(0.125,0.11;0.0731132x0.77)
# Surface Area                 Axes(0.212736,0.11;0.0731132x0.77)
# Wall Area                    Axes(0.300472,0.11;0.0731132x0.77)
# Roof Area                    Axes(0.388208,0.11;0.0731132x0.77)
# Overall Height               Axes(0.475943,0.11;0.0731132x0.77)
# Orientation                  Axes(0.563679,0.11;0.0731132x0.77)
# Glazing Area                 Axes(0.651415,0.11;0.0731132x0.77)
# Glazing Area Distribution    Axes(0.739151,0.11;0.0731132x0.77)
# Heating Load                 Axes(0.826887,0.11;0.0731132x0.77)
# dtype: object
