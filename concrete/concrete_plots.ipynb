# %%
from pandas import read_excel

# %%
df = read_excel("./Concrete_Data.xls",sheet_name="Sheet1",header=0,nrows=1030,dtype=float)
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)
# 0                                         540.0  \
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)
# 0                                                   0.0      \
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
df.loc[:, df.columns != 'Concrete compressive strength(MPa, megapascals) '].plot(
    kind="box",xlabel='From 0 to 7 : Concrete components proportions (in kg/m³)',
    title="Box plots of each component and resulting concrete compressive strength",
    figsize=(20, 8),
    use_index=False
)
# Out:
# <Axes: title={'center': 'Box plots of each component and resulting concrete compressive strength'}, xlabel='From 0 to 7 : Concrete components proportions (in kg/m³)'>

# %%
df['Concrete compressive strength(MPa, megapascals) '].plot(kind="box")
# Out:
# <Axes: >
